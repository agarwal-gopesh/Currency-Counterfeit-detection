# %%
import pandas as pd 

data = pd.read_csv('/Users/gopesh/currency-counterfeit-detection/data/processed/test.csv')
data.sample(5)
# Out:
#                              image_path authenticity  denomination  \
# 536   raw/real/10/IMG_1667833787330.jpg         real            10
# 268   raw/real/10/IMG_1667832672628.jpg         real            10
# 1256  raw/real/10/IMG20221025194554.jpg         real            10
# 1290  raw/real/20/IMG_1667840358892.jpg         real            20
# 351             raw/fake/500/1 (98).jpg         fake           500
#
#      combined_label
# 536         real_10
# 268         real_10
# 1256        real_10
# 1290        real_20
# 351        fake_500

# %%
import matplotlib.pyplot as plt
from pathlib import Path

project_root = Path.cwd().parent  # notebook se ek level upar, root tak
img_path = project_root / "data" / data.iloc[536]["image_path"]

img = plt.imread(img_path)
plt.imshow(img)
